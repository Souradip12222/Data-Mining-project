# %% [markdown]
# # PROBLEM 1

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dk=pd.read_excel('Clustering Clean Ads_Data-2.xlsx')
data1=pd.read_excel('Clustering Clean Ads_Data-2.xlsx')

# %%
dk.head()
# Out:
#      Timestamp InventoryType  Ad - Length  Ad- Width  Ad Size   Ad Type  \
# 0  2020-9-2-17       Format1          300        250    75000  Inter222
# 1  2020-9-2-10       Format1          300        250    75000  Inter227
# 2  2020-9-1-22       Format1          300        250    75000  Inter222
# 3  2020-9-3-20       Format1          300        250    75000  Inter228
# 4  2020-9-4-15       Format1          300        250    75000  Inter217
#
#   Platform Device Type   Format  Available_Impressions  Matched_Queries  \
# 0    Video     Desktop  Display                   1806              325
# 1      App      Mobile    Video                   1780              285
# 2    Video     Desktop  Display                   2727              356
# 3    Video      Mobile    Video                   2430              497
# 4      Web     Desktop    Video                   1218              242
#
#    Impressions  Clicks  Spend   Fee  Revenue     CTR  CPM  CPC
# ...

# %%
len(dk.columns)
# Out:
# 19

# %%
dk.shape
# Out:
# (23066, 21)

# %%
dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23066 entries, 0 to 23065
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Timestamp              23066 non-null  object
#  1   InventoryType          23066 non-null  object
#  2   Ad - Length            23066 non-null  int64
#  3   Ad- Width              23066 non-null  int64
#  4   Ad Size                23066 non-null  int64
#  5   Ad Type                23066 non-null  object
#  6   Platform               23066 non-null  object
#  7   Device Type            23066 non-null  object
#  8   Format                 23066 non-null  object
#  9   Available_Impressions  23066 non-null  int64
#  10  Matched_Queries        23066 non-null  int64
#  11  Impressions            23066 non-null  int64
#  12  Clicks                 23066 non-null  int64
#  13  Spend                  23066 non-null  float64
# ...

# %%
dk.describe().T
# Out:
#                          count          mean           std         min  \
# Ad - Length            23066.0  3.851631e+02  2.336514e+02    120.0000
# Ad- Width              23066.0  3.378960e+02  2.030929e+02     70.0000
# Ad Size                23066.0  9.667447e+04  6.153833e+04  33600.0000
# Available_Impressions  23066.0  2.432044e+06  4.742888e+06      1.0000
# Matched_Queries        23066.0  1.295099e+06  2.512970e+06      1.0000
# Impressions            23066.0  1.241520e+06  2.429400e+06      1.0000
# Clicks                 23066.0  1.067852e+04  1.735341e+04      1.0000
# Spend                  23066.0  2.706626e+03  4.067927e+03      0.0000
# Fee                    23066.0  3.351231e-01  3.196322e-02      0.2100
# Revenue                23066.0  1.924252e+03  3.105238e+03      0.0000
# CTR                    18330.0  7.366054e-02  7.515992e-02      0.0001
# CPM                    18330.0  7.672045e+00  6.481391e+00      0.0000
# ...

# %%
dk.duplicated().sum()
# Out:
# 0

# %%
dk.isnull().sum()
# Out:
# Timestamp                   0
# InventoryType               0
# Ad - Length                 0
# Ad- Width                   0
# Ad Size                     0
# Ad Type                     0
# Platform                    0
# Device Type                 0
# Format                      0
# Available_Impressions       0
# Matched_Queries             0
# Impressions                 0
# Clicks                      0
# Spend                       0
# Fee                         0
# Revenue                     0
# CTR                      4736
# CPM                      4736
# CPC                      4736
# dtype: int64

# %%
dk.shape
# Out:
# (23066, 19)

# %%
dk.head()
# Out:
#      Timestamp InventoryType  Ad - Length  Ad- Width  Ad Size   Ad Type  \
# 0  2020-9-2-17       Format1          300        250    75000  Inter222
# 1  2020-9-2-10       Format1          300        250    75000  Inter227
# 2  2020-9-1-22       Format1          300        250    75000  Inter222
# 3  2020-9-3-20       Format1          300        250    75000  Inter228
# 4  2020-9-4-15       Format1          300        250    75000  Inter217
#
#   Platform Device Type   Format  Available_Impressions  Matched_Queries  \
# 0    Video     Desktop  Display                   1806              325
# 1      App      Mobile    Video                   1780              285
# 2    Video     Desktop  Display                   2727              356
# 3    Video      Mobile    Video                   2430              497
# 4      Web     Desktop    Video                   1218              242
#
#    Impressions  Clicks  Spend   Fee  Revenue     CTR  CPM  CPC
# ...

# %%
# Assuming your dataset is in a DataFrame named 'df'

# Calculate CPM, treating only missing values
dk['CPM'] = np.where(dk['CPM'].isnull(), (dk['Spend'] / dk['Impressions']) * 1000, dk['CPM'])

# Calculate CPC, treating only missing values
dk['CPC'] = np.where(dk['CPC'].isnull(), dk['Spend'] / dk['Clicks'], dk['CPC'])

# Calculate CTR, treating only missing values
dk['CTR'] = np.where(dk['CTR'].isnull(), (dk['Clicks'] / dk['Impressions']) * 100, dk['CTR'])

# Print the updated DataFrame
print(dk)
# Out:
#           Timestamp InventoryType  Ad - Length  Ad- Width  Ad Size   Ad Type  \
# 0       2020-9-2-17       Format1          300        250    75000  Inter222
# 1       2020-9-2-10       Format1          300        250    75000  Inter227
# 2       2020-9-1-22       Format1          300        250    75000  Inter222
# 3       2020-9-3-20       Format1          300        250    75000  Inter228
# 4       2020-9-4-15       Format1          300        250    75000  Inter217
# ...             ...           ...          ...        ...      ...       ...
# 23061   2020-9-13-7       Format5          720        300   216000  Inter220
# 23062   2020-11-2-7       Format5          720        300   216000  Inter224
# 23063  2020-9-14-22       Format5          720        300   216000  Inter218
# 23064  2020-11-18-2       Format4          120        600    72000  inter230
# 23065   2020-9-14-0       Format5          720        300   216000  Inter221
#
# ...

# %%
dk.describe().T
# Out:
#                          count          mean           std         min  \
# Ad - Length            23066.0  3.851631e+02  2.336514e+02    120.0000
# Ad- Width              23066.0  3.378960e+02  2.030929e+02     70.0000
# Ad Size                23066.0  9.667447e+04  6.153833e+04  33600.0000
# Available_Impressions  23066.0  2.432044e+06  4.742888e+06      1.0000
# Matched_Queries        23066.0  1.295099e+06  2.512970e+06      1.0000
# Impressions            23066.0  1.241520e+06  2.429400e+06      1.0000
# Clicks                 23066.0  1.067852e+04  1.735341e+04      1.0000
# Spend                  23066.0  2.706626e+03  4.067927e+03      0.0000
# Fee                    23066.0  3.351231e-01  3.196322e-02      0.2100
# Revenue                23066.0  1.924252e+03  3.105238e+03      0.0000
# CTR                    23066.0  2.614863e+00  7.853405e+00      0.0001
# CPM                    23066.0  8.396730e+00  9.057082e+00      0.0000
# ...

# %%
dk.isnull().sum()
# Out:
# Timestamp                0
# InventoryType            0
# Ad - Length              0
# Ad- Width                0
# Ad Size                  0
# Ad Type                  0
# Platform                 0
# Device Type              0
# Format                   0
# Available_Impressions    0
# Matched_Queries          0
# Impressions              0
# Clicks                   0
# Spend                    0
# Fee                      0
# Revenue                  0
# CTR                      0
# CPM                      0
# CPC                      0
# dtype: int64

# %%
dk.columns
# Out:
# Index(['Timestamp', 'InventoryType', 'Ad - Length', 'Ad- Width', 'Ad Size',
#        'Ad Type', 'Platform', 'Device Type', 'Format', 'Available_Impressions',
#        'Matched_Queries', 'Impressions', 'Clicks', 'Spend', 'Fee', 'Revenue',
#        'CTR', 'CPM', 'CPC'],
#       dtype='object')

# %%
df = dk.drop(['Timestamp', 'InventoryType', 'Ad - Length', 'Ad- Width', 'Ad Size',
       'Ad Type', 'Platform', 'Format', 'Available_Impressions',
       'Matched_Queries', 'Impressions', 'Fee', 
       ], axis=1)

# %%
df.head()
# Out:
#   Device Type  Clicks  Spend  Revenue     CTR  CPM  CPC
# 0     Desktop       1    0.0      0.0  0.0031  0.0  0.0
# 1      Mobile       1    0.0      0.0  0.0035  0.0  0.0
# 2     Desktop       1    0.0      0.0  0.0028  0.0  0.0
# 3      Mobile       1    0.0      0.0  0.0020  0.0  0.0
# 4     Desktop       1    0.0      0.0  0.0041  0.0  0.0

# %%
df.describe().T
# Out:
#            count          mean           std     min         25%          50%  \
# Clicks   23066.0  10678.518816  17353.409363  1.0000  710.000000  4425.000000
# Spend    23066.0   2706.625689   4067.927273  0.0000   85.180000  1425.125000
# Revenue  23066.0   1924.252331   3105.238410  0.0000   55.365375   926.335000
# CTR      23066.0      2.614863      7.853405  0.0001    0.003400     0.112650
# CPM      23066.0      8.396730      9.057082  0.0000    1.750000     8.370742
# CPC      23066.0      0.336652      0.341231  0.0000    0.090000     0.140000
#
#                   75%        max
# Clicks   12793.750000  143049.00
# Spend     3121.400000   26931.87
# Revenue   2091.338150   21276.18
# CTR          0.183778     200.00
# CPM         13.040000     715.00
# CPC          0.550000       7.26

# %%
# Create a list of the columns
columns = ["Clicks", "Spend", "Revenue", "CTR", "CPM", "CPC"]

# Create a boxplot
plt.boxplot([df[column] for column in columns])

# Set the x-axis labels
plt.xticks(range(1, len(columns) + 1), columns)

# Set the y-axis label
plt.ylabel("Values")

# Set the title of the plot
plt.title("Boxplot of Clicks, Spend, Revenue, CTR, CPM, CPC")

# Show the plot
plt.show()

# %%
df.head()
# Out:
#   Device Type  Clicks  Spend  Revenue     CTR  CPM  CPC
# 0     Desktop       1    0.0      0.0  0.0031  0.0  0.0
# 1      Mobile       1    0.0      0.0  0.0035  0.0  0.0
# 2     Desktop       1    0.0      0.0  0.0028  0.0  0.0
# 3      Mobile       1    0.0      0.0  0.0020  0.0  0.0
# 4     Desktop       1    0.0      0.0  0.0041  0.0  0.0

# %%
df1=df.drop(['Device Type'],axis=1)

# %%
from scipy.stats import zscore
df_scaled = df1.apply(zscore)

# %%
df_scaled.head()
# Out:
#      Clicks     Spend   Revenue       CTR      CPM       CPC
# 0 -0.615311 -0.665372 -0.619693 -0.332572 -0.92711 -0.986603
# 1 -0.615311 -0.665372 -0.619693 -0.332521 -0.92711 -0.986603
# 2 -0.615311 -0.665372 -0.619693 -0.332610 -0.92711 -0.986603
# 3 -0.615311 -0.665372 -0.619693 -0.332712 -0.92711 -0.986603
# 4 -0.615311 -0.665372 -0.619693 -0.332444 -0.92711 -0.986603

# %%
#HIERARCHICAL & DENDOGRAM
from scipy.cluster.hierarchy import dendrogram , linkage

# %%
wardlink=linkage(df_scaled,method='ward')

# %%
dend=dendrogram(wardlink)

# %%
from scipy.cluster.hierarchy import fcluster

# %%
clusters=fcluster(wardlink,3,criterion='maxclust')
clusters
# Out:
# array([2, 2, 2, ..., 3, 3, 3], dtype=int32)

# %%
clusters=fcluster(wardlink,200,criterion='distance')
clusters
# Out:
# array([2, 2, 2, ..., 3, 3, 3], dtype=int32)

# %%
data1['clusters']=clusters

# %%
data1.head()
# Out:
#      Timestamp InventoryType  Ad - Length  Ad- Width  Ad Size   Ad Type  \
# 0  2020-9-2-17       Format1          300        250    75000  Inter222
# 1  2020-9-2-10       Format1          300        250    75000  Inter227
# 2  2020-9-1-22       Format1          300        250    75000  Inter222
# 3  2020-9-3-20       Format1          300        250    75000  Inter228
# 4  2020-9-4-15       Format1          300        250    75000  Inter217
#
#   Platform Device Type   Format  Available_Impressions  Matched_Queries  \
# 0    Video     Desktop  Display                   1806              325
# 1      App      Mobile    Video                   1780              285
# 2    Video     Desktop  Display                   2727              356
# 3    Video      Mobile    Video                   2430              497
# 4      Web     Desktop    Video                   1218              242
#
#    Impressions  Clicks  Spend   Fee  Revenue     CTR  CPM  CPC  clusters
# ...

# %%
from sklearn.cluster import KMeans

# %%
k_means = KMeans(n_clusters = 10)

# %%
k_means.fit(df_scaled)
# Out:
# KMeans(n_clusters=10)

# %%
k_means.labels_
# Out:
# array([0, 0, 0, ..., 8, 8, 8])

# %%
wss =[]

# %%
for i in range(1,11):
    KM = KMeans(n_clusters=i)
    KM.fit(df_scaled)
    wss.append(KM.inertia_)

# %%
wss
# Out:
# [138395.99999999983,
#  94245.61664618793,
#  71232.71753342017,
#  53575.33477498277,
#  39495.03784925695,
#  33582.89023755277,
#  28262.166774062996,
#  23563.452358411443,
#  20370.71986388105,
#  17789.632742752798]

# %%
plt.plot(range(1,11), wss)

# %%
k_means = KMeans(n_clusters = 5)
k_means.fit(df_scaled)
labels = k_means.labels_

# %%
dk["Clus_kmeans"] = labels
dk.head()
# Out:
#      Timestamp InventoryType  Ad - Length  Ad- Width  Ad Size   Ad Type  \
# 0  2020-9-2-17       Format1          300        250    75000  Inter222
# 1  2020-9-2-10       Format1          300        250    75000  Inter227
# 2  2020-9-1-22       Format1          300        250    75000  Inter222
# 3  2020-9-3-20       Format1          300        250    75000  Inter228
# 4  2020-9-4-15       Format1          300        250    75000  Inter217
#
#   Platform Device Type   Format  Available_Impressions  ...  Impressions  \
# 0    Video     Desktop  Display                   1806  ...          323
# 1      App      Mobile    Video                   1780  ...          285
# 2    Video     Desktop  Display                   2727  ...          355
# 3    Video      Mobile    Video                   2430  ...          495
# 4      Web     Desktop    Video                   1218  ...          242
#
#    Clicks  Spend   Fee  Revenue     CTR  CPM  CPC  Clus_kmeans  sil_width
# ...

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
silhouette_score(df_scaled,labels)
# Out:
# 0.5870819026658417

# %%
sil_width = silhouette_samples(df_scaled,labels)

# %%
dk["sil_width"] = sil_width
dk.head(5)
# Out:
#      Timestamp InventoryType  Ad - Length  Ad- Width  Ad Size   Ad Type  \
# 0  2020-9-2-17       Format1          300        250    75000  Inter222
# 1  2020-9-2-10       Format1          300        250    75000  Inter227
# 2  2020-9-1-22       Format1          300        250    75000  Inter222
# 3  2020-9-3-20       Format1          300        250    75000  Inter228
# 4  2020-9-4-15       Format1          300        250    75000  Inter217
#
#   Platform Device Type   Format  Available_Impressions  ...  Impressions  \
# 0    Video     Desktop  Display                   1806  ...          323
# 1      App      Mobile    Video                   1780  ...          285
# 2    Video     Desktop  Display                   2727  ...          355
# 3    Video      Mobile    Video                   2430  ...          495
# 4      Web     Desktop    Video                   1218  ...          242
#
#    Clicks  Spend   Fee  Revenue     CTR  CPM  CPC  Clus_kmeans  sil_width
# ...

# %%
dk.to_csv('project.csv1')

# %%
# Step 1: Determine the optimum number of clusters using silhouette score
silhouette_scores = []
for n_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=n_clusters)
    cluster_labels = kmeans.fit_predict(df_scaled)
    silhouette_scores.append(silhouette_score(df_scaled, cluster_labels))

# Plot the silhouette scores
plt.plot(range(2, 11), silhouette_scores)
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# Step 2: Choose the optimum number of clusters based on the silhouette score

# Step 3: Perform K-means clustering with the optimum number of clusters
optimum_n_clusters = 5
kmeans = KMeans(n_clusters=optimum_n_clusters)
cluster_labels = kmeans.fit_predict(df_scaled)
df_scaled['Cluster'] = cluster_labels

# Step 4: Calculate aggregate statistics
cluster_stats = df_scaled.groupby('Cluster').agg({'Clicks': 'sum', 'Spend': 'sum', 'Revenue': 'sum', 'CPM': 'mean', 'CTR': 'mean', 'CPC': 'mean'})

# Step 5: Visualize the results
cluster_stats.plot(kind='bar', subplots=True)
plt.show()

# %% [markdown]
# # PROBLEM 2

# %%
data=pd.read_excel('PCA+India+Data_Census.xlsx')

# %%
data.head()
# Out:
#    State Code  Dist.Code            State    Area Name  No_HH  TOT_M  TOT_F  \
# 0           1          1  Jammu & Kashmir      Kupwara   7707  23388  29796
# 1           1          2  Jammu & Kashmir       Badgam   6218  19585  23102
# 2           1          3  Jammu & Kashmir  Leh(Ladakh)   4452   6546  10964
# 3           1          4  Jammu & Kashmir       Kargil   1320   2784   4206
# 4           1          5  Jammu & Kashmir        Punch  11654  20591  29981
#
#    M_06  F_06  M_SC  ...  MARG_CL_0_3_M  MARG_CL_0_3_F  MARG_AL_0_3_M  \
# 0  5862  6196     3  ...           1150            749            180
# 1  4482  3733     7  ...            525            715            123
# 2  1082  1018     3  ...            114            188             44
# 3   563   677     0  ...            194            247             61
# 4  5157  4587    20  ...            874           1928            465
#
#    MARG_AL_0_3_F  MARG_HH_0_3_M  MARG_HH_0_3_F  MARG_OT_0_3_M  MARG_OT_0_3_F  \
# ...

# %%
data.shape
# Out:
# (640, 61)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 61 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State Code      640 non-null    int64
#  1   Dist.Code       640 non-null    int64
#  2   State           640 non-null    object
#  3   Area Name       640 non-null    object
#  4   No_HH           640 non-null    int64
#  5   TOT_M           640 non-null    int64
#  6   TOT_F           640 non-null    int64
#  7   M_06            640 non-null    int64
#  8   F_06            640 non-null    int64
#  9   M_SC            640 non-null    int64
#  10  F_SC            640 non-null    int64
#  11  M_ST            640 non-null    int64
#  12  F_ST            640 non-null    int64
#  13  M_LIT           640 non-null    int64
#  14  F_LIT           640 non-null    int64
#  15  M_ILL           640 non-null    int64
#  16  F_ILL           640 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# State Code       0
# Dist.Code        0
# State            0
# Area Name        0
# No_HH            0
#                 ..
# MARG_HH_0_3_F    0
# MARG_OT_0_3_M    0
# MARG_OT_0_3_F    0
# NON_WORK_M       0
# NON_WORK_F       0
# Length: 61, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Select the desired variables for EDA
variables = ['No_HH', 'TOT_M', 'TOT_F', 'M_06', 'F_06']

# Calculate gender ratio for each state
data['Gender_Ratio'] = data['TOT_F'] / data['TOT_M']

# Find the state with the highest and lowest gender ratio
state_with_highest_ratio = data.loc[data['Gender_Ratio'].idxmax(), 'State']
state_with_lowest_ratio = data.loc[data['Gender_Ratio'].idxmin(), 'State']

# Calculate gender ratio for each district
data['District_Gender_Ratio'] = data['TOT_F'] / data['TOT_M']

# Find the district with the highest and lowest gender ratio
district_with_highest_ratio = data.loc[data['District_Gender_Ratio'].idxmax(), 'Dist.Code']
district_with_lowest_ratio = data.loc[data['District_Gender_Ratio'].idxmin(), 'Dist.Code']

# Plotting the gender ratio by state
plt.figure(figsize=(10, 6))
plt.bar(data['State'], data['Gender_Ratio'])
plt.xticks(rotation='vertical')
plt.xlabel('State')
plt.ylabel('Gender Ratio')
plt.title('Gender Ratio by State')
plt.show()

# Plotting the gender ratio by district
plt.figure(figsize=(10, 6))
plt.bar(data['Dist.Code'], data['District_Gender_Ratio'])
plt.xticks(rotation='vertical')
plt.xlabel('Dist.Code')
plt.ylabel('Gender Ratio')
plt.title('Gender Ratio by District')
plt.show()

# Additional exploratory analysis using the selected variables
selected_data = data[variables]
# You can perform further analysis, such as calculating statistics, plotting histograms, etc., on the selected_data DataFrame.

# Print the results
print("State with the highest gender ratio:", state_with_highest_ratio)
print("State with the lowest gender ratio:", state_with_lowest_ratio)
print("District with the highest gender ratio:", district_with_highest_ratio)
print("District with the lowest gender ratio:", district_with_lowest_ratio)
# Out:
# State with the highest gender ratio: Andhra Pradesh
# State with the lowest gender ratio: Lakshadweep
# District with the highest gender ratio: 547
# District with the lowest gender ratio: 587

# %%
df_pca1=data.drop(['State Code', 'Dist.Code', 'State', 'Area Name', 'No_HH', 'TOT_M','TOT_F','M_SC', 'F_SC', 'M_ST', 'F_ST', 'M_LIT','F_LIT', 'M_ILL', 'F_ILL', 'TOT_WORK_M', 'TOT_WORK_F', 'MAINWORK_M','MAINWORK_F','MARGWORK_M','MARGWORK_F', 'MARG_CL_M', 'MARG_CL_F', 'MARG_AL_M', 'MARG_AL_F','MARG_HH_M', 'MARG_HH_F', 'MARG_OT_M','MARG_OT_F','Gender_Ratio','District_Gender_Ratio'],axis=1)

# %%
df_pca1.head()
# Out:
#    M_06  F_06  MAIN_CL_M  MAIN_CL_F  MAIN_AL_M  MAIN_AL_F  MAIN_HH_M  \
# 0  5862  6196        486        235        407        143         78
# 1  4482  3733       1098        357        442        108        538
# 2  1082  1018        519       1205         36         71         19
# 3   563   677         35        102          8         24          9
# 4  5157  4587        743        766        254        237         35
#
#    MAIN_HH_F  MAIN_OT_M  MAIN_OT_F  ...  MARG_CL_0_3_M  MARG_CL_0_3_F  \
# 0         86       1792        811  ...           1150            749
# 1        343       2550        925  ...            525            715
# 2         55       1366       1592  ...            114            188
# 3          6        439        276  ...            194            247
# 4         64       1491       1200  ...            874           1928
#
#    MARG_AL_0_3_M  MARG_AL_0_3_F  MARG_HH_0_3_M  MARG_HH_0_3_F  MARG_OT_0_3_M  \
# ...

# %%
df_pca1.describe().T
# Out:
#                 count          mean           std    min       25%      50%  \
# M_06            640.0  12309.098438  11500.906881   56.0   4733.75   9159.0
# F_06            640.0  11942.300000  11326.294567   56.0   4672.25   8663.0
# MAIN_CL_M       640.0   5424.342188   4739.161969    0.0   2023.50   4160.5
# MAIN_CL_F       640.0   5486.042188   5326.362728    0.0   1920.25   3908.5
# MAIN_AL_M       640.0   5849.109375   6399.507966    0.0   1070.25   3936.5
# MAIN_AL_F       640.0   8925.995312  12864.287584    0.0   1408.75   3933.5
# MAIN_HH_M       640.0    883.893750   1278.642345    0.0    187.50    498.5
# MAIN_HH_F       640.0   1380.773438   3179.414449    0.0    248.75    540.5
# MAIN_OT_M       640.0  18047.101562  26068.480886   36.0   3997.50   9598.0
# MAIN_OT_F       640.0  12406.035938  18972.202369  153.0   3142.50   6380.5
# MARGWORK_3_6_M  640.0  41948.168750  39045.316918  291.0  16208.25  30315.0
# ...

# %%
#Check the number of features
len(df_pca1.columns)
# Out:
# 32

# %%
#Check for presence of outliers in each feature
plt.figure(figsize = (20,10))
feature_list = df_pca1.columns
for i in range(len(feature_list)):
    plt.subplot(4,8, i + 1)
    sns.boxplot(y = df_pca1[feature_list[i]], data = df_pca1)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %%
#Scale the data
from scipy.stats import zscore
df_pca_scaled = df_pca1.apply(zscore)

# %%
#Check the data post scaling
df_pca_scaled.head()
# Out:
#        M_06      F_06  MAIN_CL_M  MAIN_CL_F  MAIN_AL_M  MAIN_AL_F  MAIN_HH_M  \
# 0 -0.561012 -0.507738  -1.042844  -0.986630  -0.851060  -0.683276  -0.630766
# 1 -0.681096 -0.725367  -0.913606  -0.963707  -0.845587  -0.685999  -0.270728
# 2 -0.976956 -0.965262  -1.035875  -0.804375  -0.909079  -0.688878  -0.676945
# 3 -1.022118 -0.995393  -1.138083  -1.011620  -0.913457  -0.692534  -0.684772
# 4 -0.622359 -0.649908  -0.988572  -0.886859  -0.874987  -0.675964  -0.664422
#
#    MAIN_HH_F  MAIN_OT_M  MAIN_OT_F  ...  MARG_CL_0_3_M  MARG_CL_0_3_F  \
# 0  -0.407555  -0.624042  -0.611637  ...      -0.163229      -0.720610
# 1  -0.326659  -0.594942  -0.605624  ...      -0.583103      -0.732811
# 2  -0.417313  -0.640396  -0.570440  ...      -0.859212      -0.921931
# 3  -0.432737  -0.675984  -0.639858  ...      -0.805468      -0.900758
# 4  -0.414480  -0.635597  -0.591118  ...      -0.348645      -0.297513
#
#    MARG_AL_0_3_M  MARG_AL_0_3_F  MARG_HH_0_3_M  MARG_HH_0_3_F  MARG_OT_0_3_M  \
# ...

# %%
#Check for presence of outliers in each feature
plt.figure(figsize = (20,10))
feature_list = df_pca_scaled.columns
for i in range(len(feature_list)):
    plt.subplot(4,8, i + 1)
    sns.boxplot(y = df_pca_scaled[feature_list[i]], data = df_pca_scaled)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %%
#Define a function which returns the Upper and Lower limit to detect outliers for each feature
def remove_outlier(col):
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
#Cap & floor the values beyond the outlier boundaries
for i in feature_list:
    LL, UL = remove_outlier(df_pca1[i])
    df_pca1[i] = np.where(df_pca1[i] > UL, UL, df_pca1[i])
    df_pca1[i] = np.where(df_pca1[i] < LL, LL, df_pca1[i])

# %%
#Check to verify if outliers have been treated
plt.figure(figsize = (20,10))
feature_list = df_pca1.columns
for i in range(len(feature_list)):
    plt.subplot(4,8, i + 1)
    sns.boxplot(y = df_pca1[feature_list[i]], data = df_pca1)
    plt.title('Boxplot of {}'.format(feature_list[i]))
    plt.tight_layout()

# %%
#Check for presence of correlations
plt.figure(figsize = (20,10))
sns.heatmap(df_pca_scaled.corr(), annot=True,fmt='.2f');

# %%
#Confirm the statistical significance of correlations
#H0: Correlations are not significant, H1: There are significant correlations
#Reject H0 if p-value < 0.05
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df_pca_scaled)
p_value
# Out:
# nan

# %%
#Confirm the adequacy of sample size. 
#Note: Above 0.7 is good, below 0.5 is not acceptable
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all,kmo_model=calculate_kmo(df_pca_scaled)
kmo_model
# Out:
# 0.792926321791567

# %%
#Apply PCA taking all features
from sklearn.decomposition import PCA
pca = PCA(n_components=32, random_state=123)
pca_transformed = pca.fit_transform(df_pca_scaled)

# %%
#Extract eigen vectors
pca.components_
# Out:
# array([[ 2.20242319e-01,  2.21093158e-01,  1.43085470e-01, ...,
#          1.91471797e-01,  2.03415779e-01,  1.75908991e-01],
#        [-7.22306163e-02, -7.14403952e-02,  6.72680976e-02, ...,
#         -1.20491990e-02, -1.37279587e-01, -1.37716338e-01],
#        [ 6.01255452e-02,  5.20051231e-02, -1.35311955e-01, ...,
#         -8.18307020e-02,  1.64555706e-01,  1.58778716e-01],
#        ...,
#        [ 0.00000000e+00,  6.00943712e-16, -7.81498118e-18, ...,
#         -5.02457499e-02, -2.21226619e-01, -1.47652931e-01],
#        [-0.00000000e+00, -7.95127495e-16, -1.51580317e-16, ...,
#         -5.25987928e-02,  1.55833750e-01, -1.54567619e-01],
#        [ 0.00000000e+00, -1.88026678e-16,  1.35713020e-16, ...,
#          2.91069639e-02, -1.81952084e-01,  8.55341707e-02]])

# %%
#Check the eigen values
#Note: This is always returned in descending order
pca.explained_variance_
# Out:
# array([1.67045182e+01, 4.69606265e+00, 2.83513020e+00, 2.17927634e+00,
#        1.52328286e+00, 1.08185716e+00, 5.65517481e-01, 5.02723760e-01,
#        4.49522682e-01, 2.90472892e-01, 2.63724883e-01, 2.07655725e-01,
#        1.94338053e-01, 9.84867599e-02, 9.49801552e-02, 8.47683073e-02,
#        7.10468002e-02, 5.01922303e-02, 3.33603464e-02, 2.83191119e-02,
#        2.43976415e-02, 2.22493102e-02, 1.65789391e-02, 1.11052892e-02,
#        9.31481600e-03, 6.11325597e-03, 4.07552691e-03, 1.00686343e-03,
#        1.27852857e-31, 1.27852857e-31, 1.27852857e-31, 1.27852857e-31])

# %%
#Check the explained variance for each PC
#Note: Explained variance = (eigen value of each PC)/(sum of eigen values of all PCs)
pca.explained_variance_ratio_
# Out:
# array([5.21200544e-01, 1.46522658e-01, 8.84593846e-02, 6.79959757e-02,
#        4.75282104e-02, 3.37552111e-02, 1.76448081e-02, 1.56855704e-02,
#        1.40256345e-02, 9.06309464e-03, 8.22852539e-03, 6.47910197e-03,
#        6.06357500e-03, 3.07290232e-03, 2.96349215e-03, 2.64487052e-03,
#        2.21674342e-03, 1.56605640e-03, 1.04088190e-03, 8.83589477e-04,
#        7.61235007e-04, 6.94204550e-04, 5.17282329e-04, 3.46498036e-04,
#        2.90633175e-04, 1.90740750e-04, 1.27161216e-04, 3.14153190e-05,
#        3.98915895e-33, 3.98915895e-33, 3.98915895e-33, 3.98915895e-33])

# %%
#Create a dataframe containing the loadings or coefficients of all PCs
df_extracted_loadings = pd.DataFrame(pca.components_.T, 
                                     columns = ['PC1','PC2', 'PC3', 'PC4', 'PC5', 'PC6','PC7','PC8', 'PC9', 'PC10', 'PC11', 'PC12','PC13','PC14','PC15','PC16','PC17',
                                               'PC18','PC19','PC20','PC21','PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32'],
                                    index = df_pca_scaled.columns)

# %%
df_extracted_loadings
# Out:
#                      PC1       PC2       PC3       PC4       PC5       PC6  \
# M_06            0.220242 -0.072231  0.060126 -0.089421 -0.076390 -0.245658
# F_06            0.221093 -0.071440  0.052005 -0.082975 -0.077436 -0.243836
# MAIN_CL_M       0.143085  0.067268 -0.135312 -0.229881  0.224741 -0.427091
# MAIN_CL_F       0.102121  0.134823 -0.063847 -0.429103  0.241817 -0.145028
# MAIN_AL_M       0.146751 -0.061067 -0.339117 -0.248112  0.055159 -0.004519
# MAIN_AL_F       0.086506 -0.064004 -0.340803 -0.408217  0.033088  0.190805
# MAIN_HH_M       0.176699 -0.155524  0.034083  0.097778  0.290354 -0.133125
# MAIN_HH_F       0.108824 -0.145580 -0.072722  0.024505  0.479114  0.331707
# MAIN_OT_M       0.148139 -0.292957  0.193478 -0.131500 -0.023971  0.083226
# MAIN_OT_F       0.128538 -0.278386  0.149628 -0.197364 -0.012898  0.195896
# MARGWORK_3_6_M  0.221532 -0.098145  0.071304 -0.103262 -0.069945 -0.198025
# ...

# %%
#Create a scree plot
plt.figure(figsize=(8,5))
sns.lineplot(y=pca.explained_variance_ratio_ ,x=range(1,33),marker='o')
plt.xlabel('Number of Components',fontsize=32)
plt.ylabel('Variance Explained',fontsize=10)
plt.title('Scree Plot',fontsize=12)
plt.grid()
plt.show()

# %%
#Check the cumlative explained variance ratio to find a cut off for selecting the number of PCs
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.52120054, 0.6677232 , 0.75618259, 0.82417856, 0.87170677,
#        0.90546198, 0.92310679, 0.93879236, 0.952818  , 0.96188109,
#        0.97010962, 0.97658872, 0.98265229, 0.9857252 , 0.98868869,
#        0.99133356, 0.9935503 , 0.99511636, 0.99615724, 0.99704083,
#        0.99780206, 0.99849627, 0.99901355, 0.99936005, 0.99965068,
#        0.99984142, 0.99996858, 1.        , 1.        , 1.        ,
#        1.        , 1.        ])

# %%
#Choose the PCs basis cumulative explained variance
df_selected = df_extracted_loadings[['PC1','PC2', 'PC3', 'PC4', 'PC5','PC6']]

# %%
#Check the selected PCs
df_selected
# Out:
#                      PC1       PC2       PC3       PC4       PC5       PC6
# M_06            0.220242 -0.072231  0.060126 -0.089421 -0.076390 -0.245658
# F_06            0.221093 -0.071440  0.052005 -0.082975 -0.077436 -0.243836
# MAIN_CL_M       0.143085  0.067268 -0.135312 -0.229881  0.224741 -0.427091
# MAIN_CL_F       0.102121  0.134823 -0.063847 -0.429103  0.241817 -0.145028
# MAIN_AL_M       0.146751 -0.061067 -0.339117 -0.248112  0.055159 -0.004519
# MAIN_AL_F       0.086506 -0.064004 -0.340803 -0.408217  0.033088  0.190805
# MAIN_HH_M       0.176699 -0.155524  0.034083  0.097778  0.290354 -0.133125
# MAIN_HH_F       0.108824 -0.145580 -0.072722  0.024505  0.479114  0.331707
# MAIN_OT_M       0.148139 -0.292957  0.193478 -0.131500 -0.023971  0.083226
# MAIN_OT_F       0.128538 -0.278386  0.149628 -0.197364 -0.012898  0.195896
# MARGWORK_3_6_M  0.221532 -0.098145  0.071304 -0.103262 -0.069945 -0.198025
# ...

# %%
#To check as to how the original features matter to each PC
#Note: Here we are only considering the absolute values
plt.figure(figsize = (12,8))
for i in range(len(df_selected.columns)):
    plt.subplot(3,2,i+1)
    abs(df_selected[df_selected.columns[i]]).T.sort_values(ascending = False).plot.bar()
    plt.yticks(np.arange(0,1.2,.2))
    plt.title('Abs. loadings of {}'.format(df_selected.columns[i]))
    plt.tight_layout()

# %%
#Compare how the original features influence various PCs
plt.figure(figsize = (12,8))
sns.heatmap(abs(df_selected), annot = True, cmap = 'Blues',fmt = '.2f');

# %%
#In order to calculate PC scores we need loadings, below:
df_selected
# Out:
#                      PC1       PC2       PC3       PC4       PC5       PC6
# M_06            0.220242 -0.072231  0.060126 -0.089421 -0.076390 -0.245658
# F_06            0.221093 -0.071440  0.052005 -0.082975 -0.077436 -0.243836
# MAIN_CL_M       0.143085  0.067268 -0.135312 -0.229881  0.224741 -0.427091
# MAIN_CL_F       0.102121  0.134823 -0.063847 -0.429103  0.241817 -0.145028
# MAIN_AL_M       0.146751 -0.061067 -0.339117 -0.248112  0.055159 -0.004519
# MAIN_AL_F       0.086506 -0.064004 -0.340803 -0.408217  0.033088  0.190805
# MAIN_HH_M       0.176699 -0.155524  0.034083  0.097778  0.290354 -0.133125
# MAIN_HH_F       0.108824 -0.145580 -0.072722  0.024505  0.479114  0.331707
# MAIN_OT_M       0.148139 -0.292957  0.193478 -0.131500 -0.023971  0.083226
# MAIN_OT_F       0.128538 -0.278386  0.149628 -0.197364 -0.012898  0.195896
# MARGWORK_3_6_M  0.221532 -0.098145  0.071304 -0.103262 -0.069945 -0.198025
# ...

# %%
pca = PCA(n_components=6, random_state=123)
pca_final = pca.fit_transform(df_pca_scaled)

# %%
pca_final_df = pd.DataFrame(pca_final, columns = df_selected.columns)
pca_final_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6
# 0 -3.019921  0.044884  0.386464  1.289217 -0.388381 -0.219186
# 1 -3.153442 -0.217434  0.279333  1.496650  0.432831 -0.176217
# 2 -4.248700 -0.129185  0.419551  0.725369  0.019411  0.090405
# 3 -4.434368 -0.294144  0.298506  0.983085 -0.090684  0.138994
# 4 -2.912614  0.759319  1.063542  0.786703 -0.097044  0.370937

# %%
#Check for presence of correlations among teh PCs
plt.figure(figsize = (8,7))
sns.heatmap(pca_final_df.corr(), annot=True,fmt='.2f',cbar=False);
